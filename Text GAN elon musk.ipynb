# %%
from __future__ import print_function
import pdb
import math
from math import ceil
import numpy as np
import sys
import pandas as pd
import re

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F
import torch.optim as optim
import torch.autograd as autograd

import helpers

# %%
VOCAB_SIZE = 8000
MAX_SEQ_LEN = 20
START_LETTER = 0
BATCH_SIZE = 32
MLE_TRAIN_EPOCHS = 100
ADV_TRAIN_EPOCHS = 50
POS_NEG_SAMPLES = 2500

GEN_EMBEDDING_DIM = 32
GEN_HIDDEN_DIM = 32
DIS_EMBEDDING_DIM = 64
DIS_HIDDEN_DIM = 64

data_path = './elonmusk.csv'

# %%
df = pd.DataFrame.from_csv(data_path, encoding = 'ISO-8859-1')
df
# Out:
#                                                      Tweet  \
# row ID
# Row0     @MeltingIce Assuming max acceleration of 2 to ...
# Row1     RT @SpaceX: BFR is capable of transporting sat...
# Row2                                        @bigajm Yup :)
# Row3                        Part 2 https://t.co/8Fvu57muhM
# Row4     Fly to most places on Earth in under 30 mins a...
# Row5     RT @SpaceX: Supporting the creation of a perma...
# Row6     BFR will take you anywhere on Earth in less th...
# Row7     Mars City\nOpposite of Earth. Dawn and dusk sk...
# Row8               Moon Base Alpha https://t.co/voY8qEW9kl
# Row9     Will be announcing something really special at...
# Row10    RT @SpaceX: Nine years ago today, Falcon 1 bec...
# Row11           @kevinroose Just another day in the office
# Row12    @Fashionista_com @mayemusk Congrats Mom! I lov...
# Row13    RT @mayemusk: .@covergirl I'm so excited to sa...
# Row14    Prev ideas for paying ~$10B dev cost incl. Kic...
# Row15    Headed to Adelaide soon to describe new BFR pl...
# Row16           @El_Deano @Daimler @Jalopnik Yes, I did :)
# Row17    Good NYT article from several years ago about ...
# Row18                                 @AdrianZorrillaC Yes
# Row19    Simulation of how the SpaceX Interplanetary Sp...
# Row20                                        @Daimler Good
# Row21    Major improvements & some unexpected applicati...
# Row22    Presentation of @SpaceX Interplanetary Spacesh...
# Row23    @USATODAYmoney @NathanBomey That's not a lot o...
# Row24    RT @MotorTrend: Shocking winner of our latest,...
# Row25    @Its_Subhamk Don't give up if the cause is imp...
# Row26    @JimHeaney Absolutely. Moreover, we expect to ...
# Row27           @Richwsadler Does my hivemind count as me?
# Row28    @Bobby_Gupta Def not ok. Just sent a reminder ...
# Row29    @rishabagrwl2013 In discussions with national ...
# ...                                                    ...
# Row3188  Tesla was just approved for a full Class 1 Mas...
# Row3189  Told my kids (age 8 and 6) that we were going ...
# Row3190  Congrats to @dmetcalf for being the first to d...
# Row3191  Interesting possible answer to the Fermi Parad...
# Row3192  RT @Slate: New government study says we could ...
# Row3193  Am happy to report that Tesla was narrowly cas...
# Row3194  Uranium ore now available on Amazon! So much m...
# Row3195                           @shervin Thanks Shervin!
# Row3196  RT @TheEconomist: Mexico is changing in ways t...
# Row3197  Can't put my finger on it, but for some reason...
# Row3198  But if humanity wishes to become a multi-plane...
# Row3199  And, yes, I do in fact know that this sounds c...
# Row3200  Millions of people needed for Mars colony, so ...
# Row3201  Short vid of the recent @SpaceX mission to the...
# Row3202  @cthorm SS Heart of Gold powered by the Infini...
# Row3203  My talk for the Royal Aeronautical Society is ...
# Row3204  Liam Neeson's Life's Too Short sketch is super...
# Row3205  RT @neokoenig: @elonmusk if anyone has issues ...
# Row3206  On the plus side...?@newscientist: #Climate ch...
# Row3207  Gave a talk on energy and transport at Oxford ...
# Row3208                           @Thomas_Tregner Exactly!
# Row3209  Love this picture of the Curiousity rover on M...
# Row3210  RT @westcoastbill: HELLO?.  ?@wired: BREAKING:...
# Row3211  Btw, I don't think Apple is doomed. Just won't...
# Row3212  Mass. judge denies auto dealers' demand to kil...
# Row3213  @YOUSRC Amos's article was fair, but his edito...
# Row3214  These articles in Space News describe why Aria...
# Row3215  Was misquoted by BBC as saying Europe's rocket...
# Row3216  Just returned from a trip to London and Oxford...
# Row3217  RT @Jon_Favreau: My Model S just arrived and I...
#
#                         Time   Retweet from      User
# row ID
# Row0     2017-09-29 17:39:19            NaN  elonmusk
# Row1     2017-09-29 10:44:54         SpaceX  elonmusk
# Row2     2017-09-29 10:39:57            NaN  elonmusk
# Row3     2017-09-29 09:56:12            NaN  elonmusk
# Row4     2017-09-29 09:19:21            NaN  elonmusk
# Row5     2017-09-29 08:57:29         SpaceX  elonmusk
# Row6     2017-09-29 08:53:00            NaN  elonmusk
# Row7     2017-09-29 06:03:32            NaN  elonmusk
# Row8     2017-09-29 05:44:55            NaN  elonmusk
# Row9     2017-09-29 02:36:17            NaN  elonmusk
# Row10    2017-09-29 02:32:54         SpaceX  elonmusk
# Row11    2017-09-28 22:44:16            NaN  elonmusk
# Row12    2017-09-28 07:53:52            NaN  elonmusk
# Row13    2017-09-28 07:53:24       mayemusk  elonmusk
# Row14    2017-09-27 03:18:59            NaN  elonmusk
# Row15    2017-09-27 03:03:12            NaN  elonmusk
# Row16    2017-09-26 15:04:25            NaN  elonmusk
# Row17    2017-09-26 05:39:25            NaN  elonmusk
# Row18    2017-09-26 03:13:54            NaN  elonmusk
# Row19    2017-09-26 03:11:58            NaN  elonmusk
# Row20    2017-09-25 21:33:27            NaN  elonmusk
# Row21    2017-09-25 13:15:05            NaN  elonmusk
# Row22    2017-09-25 13:12:44            NaN  elonmusk
# Row23    2017-09-24 22:31:24            NaN  elonmusk
# Row24    2017-09-22 02:31:56     MotorTrend  elonmusk
# Row25    2017-09-20 19:25:08            NaN  elonmusk
# Row26    2017-09-19 19:36:39            NaN  elonmusk
# Row27    2017-09-16 09:16:04            NaN  elonmusk
# Row28    2017-09-16 05:16:49            NaN  elonmusk
# Row29    2017-09-16 03:28:05            NaN  elonmusk
# ...                      ...            ...       ...
# Row3188  2012-12-11 04:54:30            NaN  elonmusk
# Row3189  2012-12-10 01:13:23            NaN  elonmusk
# Row3190  2012-12-09 10:38:48            NaN  elonmusk
# Row3191  2012-12-05 07:20:41            NaN  elonmusk
# Row3192  2012-12-04 07:34:57          Slate  elonmusk
# Row3193  2012-12-04 06:40:56            NaN  elonmusk
# Row3194  2012-12-02 23:12:03            NaN  elonmusk
# Row3195  2012-11-29 12:00:15            NaN  elonmusk
# Row3196  2012-11-28 08:14:15   TheEconomist  elonmusk
# Row3197  2012-11-28 03:19:37            NaN  elonmusk
# Row3198  2012-11-27 20:00:03            NaN  elonmusk
# Row3199  2012-11-27 19:55:32            NaN  elonmusk
# Row3200  2012-11-27 19:48:23            NaN  elonmusk
# Row3201  2012-11-25 03:53:51            NaN  elonmusk
# Row3202  2012-11-24 02:07:43            NaN  elonmusk
# Row3203  2012-11-23 21:45:06            NaN  elonmusk
# Row3204  2012-11-23 05:16:03            NaN  elonmusk
# Row3205  2012-11-22 22:49:55      neokoenig  elonmusk
# Row3206  2012-11-22 18:32:13            NaN  elonmusk
# Row3207  2012-11-22 17:55:04            NaN  elonmusk
# Row3208  2012-11-21 07:14:07            NaN  elonmusk
# Row3209  2012-11-21 05:01:08            NaN  elonmusk
# Row3210  2012-11-21 02:37:03  westcoastbill  elonmusk
# Row3211  2012-11-20 21:32:50            NaN  elonmusk
# Row3212  2012-11-20 21:22:29            NaN  elonmusk
# Row3213  2012-11-20 08:52:03            NaN  elonmusk
# Row3214  2012-11-20 08:38:31            NaN  elonmusk
# Row3215  2012-11-20 08:30:44            NaN  elonmusk
# Row3216  2012-11-19 08:59:46            NaN  elonmusk
# Row3217  2012-11-16 17:59:47    Jon_Favreau  elonmusk
#
# [3218 rows x 4 columns]

# %%
tweet_tokens = []

SOS_token = 0
EOS_token = 1
UNK_token = 2
index2word = {0: '<SOS>', 1: '<EOS>', 2: '<UNK>'}
word2index = {'<UNK>': 2}
word2count = {'<UNK>': 0}
n_words = 3

for s in df.Tweet:  
    s = s.lower()
    tokens = helpers.preprocess(s)
    
    tweet_tokens.append(SOS_token)
    
    for word in tokens:
        word = re.sub(r'<[^>]+>', '<HTML>', word)
        word = re.sub(r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', '<URL>', word)
        #word = re.sub(r'(?:@[\w_]+)', '<@-mentions>', word)
        if word not in word2index:
            word2count[word] = 1
            word2index[word] = n_words
            index2word[n_words] = word
            n_words += 1
        else:
            word2count[word] += 1
            
        tweet_tokens.append(word2index[word])
        
    tweet_tokens.append(EOS_token)
test_tokens = tweet_tokens[MAX_SEQ_LEN*POS_NEG_SAMPLES+1:]
tweet_tokens = tweet_tokens[:MAX_SEQ_LEN*POS_NEG_SAMPLES]
oracle_samples = torch.LongTensor(tweet_tokens).view(POS_NEG_SAMPLES,MAX_SEQ_LEN).type(torch.LongTensor)

# %%
class Generator(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, max_seq_len, oracle_init=False):
        super(Generator, self).__init__()
        self.hidden_dim = hidden_dim
        self.embedding_dim = embedding_dim
        self.max_seq_len = max_seq_len
        self.vocab_size = vocab_size

        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.gru = nn.GRU(embedding_dim, hidden_dim)
        self.gru2out = nn.Linear(hidden_dim, vocab_size)

        if oracle_init:
            for p in self.parameters():
                init.normal(p, 0, 1)

    def init_hidden(self, batch_size=1):
        h = autograd.Variable(torch.zeros(1, batch_size, self.hidden_dim))
        return h

    def forward(self, inp, hidden):
        # input dim                                             # batch_size
        emb = self.embeddings(inp)                              # batch_size x embedding_dim
        emb = emb.view(1, -1, self.embedding_dim)               # 1 x batch_size x embedding_dim
        out, hidden = self.gru(emb, hidden)                     # 1 x batch_size x hidden_dim (out)
        out = self.gru2out(out.view(-1, self.hidden_dim))       # batch_size x vocab_size
        out = F.log_softmax(out, dim=0)
        return out, hidden

    def sample(self, num_samples, start_letter=0):

        samples = torch.zeros(num_samples, self.max_seq_len).type(torch.LongTensor)

        h = self.init_hidden(num_samples)
        inp = autograd.Variable(torch.LongTensor([start_letter]*num_samples))

        for i in range(self.max_seq_len):
            out, h = self.forward(inp, h)               # out: num_samples x vocab_size
            out = torch.multinomial(torch.exp(out), 1)  # num_samples x 1 (sampling from each row)
            samples[:, i] = out.data

            inp = out.view(-1)

        return samples

    def batchNLLLoss(self, inp, target):
        loss_fn = nn.NLLLoss()
        batch_size, seq_len = inp.size()
        inp = inp.permute(1, 0)           # seq_len x batch_size
        target = target.permute(1, 0)     # seq_len x batch_size
        h = self.init_hidden(batch_size)

        loss = 0
        for i in range(seq_len):
            out, h = self.forward(inp[i], h)
            loss += loss_fn(out, target[i])

        return loss     # per batch

    def batchPGLoss(self, inp, target, reward):
        batch_size, seq_len = inp.size()
        inp = inp.permute(1, 0)          # seq_len x batch_size
        target = target.permute(1, 0)    # seq_len x batch_size
        h = self.init_hidden(batch_size)

        loss = 0
        for i in range(seq_len):
            out, h = self.forward(inp[i], h)
            for j in range(batch_size):
                loss += -out[j][target.data[i][j]]*reward[j]     # log(P(y_t|Y_1:Y_{t-1})) * Q

        return loss/batch_size

# %%
class Discriminator(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, max_seq_len, dropout=0.2):
        super(Discriminator, self).__init__()
        self.hidden_dim = hidden_dim
        self.embedding_dim = embedding_dim
        self.max_seq_len = max_seq_len

        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.gru = nn.GRU(embedding_dim, hidden_dim, num_layers=2, bidirectional=True, dropout=dropout)
        self.gru2hidden = nn.Linear(2*2*hidden_dim, hidden_dim)
        self.dropout_linear = nn.Dropout(p=dropout)
        self.hidden2out = nn.Linear(hidden_dim, 1)

    def init_hidden(self, batch_size):
        h = autograd.Variable(torch.zeros(2*2*1, batch_size, self.hidden_dim))
        return h

    def forward(self, input, hidden):
        # input dim                                                # batch_size x seq_len
        emb = self.embeddings(input)                               # batch_size x seq_len x embedding_dim
        emb = emb.permute(1, 0, 2)                                 # seq_len x batch_size x embedding_dim
        _, hidden = self.gru(emb, hidden)                          # 4 x batch_size x hidden_dim
        hidden = hidden.permute(1, 0, 2).contiguous()              # batch_size x 4 x hidden_dim
        out = self.gru2hidden(hidden.view(-1, 4*self.hidden_dim))  # batch_size x 4*hidden_dim
        out = F.tanh(out)
        out = self.dropout_linear(out)
        out = self.hidden2out(out)                                 # batch_size x 1
        out = F.sigmoid(out)
        return out

    def batchClassify(self, inp):
        h = self.init_hidden(inp.size()[0])
        out = self.forward(inp, h)
        return out.view(-1)

    def batchBCELoss(self, inp, target):
        loss_fn = nn.BCELoss()
        h = self.init_hidden(inp.size()[0])
        out = self.forward(inp, h)
        return loss_fn(out, target)

# %%
def train_generator_MLE(gen, gen_opt, oracle, real_data_samples, epochs):
    for epoch in range(epochs):
        print('epoch %d : ' % (epoch + 1), end='')
        sys.stdout.flush()
        total_loss = 0

        for i in range(0, POS_NEG_SAMPLES, BATCH_SIZE):
            inp, target = helpers.prepare_generator_batch(real_data_samples[i:i + BATCH_SIZE], start_letter=START_LETTER)
            gen_opt.zero_grad()
            loss = gen.batchNLLLoss(inp, target)
            loss.backward()
            gen_opt.step()

            total_loss += loss.data[0]

            if (i / BATCH_SIZE) % ceil(
                            ceil(POS_NEG_SAMPLES / float(BATCH_SIZE)) / 10.) == 0:  # roughly every 10% of an epoch
                print('.', end='')
                sys.stdout.flush()
                
        total_loss = total_loss / ceil(POS_NEG_SAMPLES / float(BATCH_SIZE)) / MAX_SEQ_LEN
        oracle_loss = helpers.batchwise_oracle_nll(gen, oracle, POS_NEG_SAMPLES, BATCH_SIZE, MAX_SEQ_LEN, start_letter=START_LETTER)

        print(' average_train_NLL = %.4f, oracle_sample_NLL = %.4f' % (total_loss, oracle_loss))

# %%
def train_generator_PG(gen, gen_opt, oracle, dis, num_batches):
    for batch in range(num_batches):
        s = gen.sample(BATCH_SIZE*2)
        inp, target = helpers.prepare_generator_batch(s, start_letter=START_LETTER)
        rewards = dis.batchClassify(target)

        gen_opt.zero_grad()
        pg_loss = gen.batchPGLoss(inp, target, rewards)
        pg_loss.backward()
        gen_opt.step()
        
    oracle_loss = helpers.batchwise_oracle_nll(gen, oracle, POS_NEG_SAMPLES, BATCH_SIZE, MAX_SEQ_LEN, start_letter=START_LETTER)

    print(' oracle_sample_NLL = %.4f' % oracle_loss)

# %%
def train_discriminator(discriminator, dis_opt, real_data_samples, generator, oracle, d_steps, epochs):
    pos_val = oracle.sample(100)
    neg_val = generator.sample(100)
    val_inp, val_target = helpers.prepare_discriminator_data(pos_val, neg_val)

    for d_step in range(d_steps):
        s = helpers.batchwise_sample(generator, POS_NEG_SAMPLES, BATCH_SIZE)
        dis_inp, dis_target = helpers.prepare_discriminator_data(real_data_samples, s)
        for epoch in range(epochs):
            print('d-step %d epoch %d : ' % (d_step + 1, epoch + 1), end='')
            sys.stdout.flush()
            total_loss = 0
            total_acc = 0

            for i in range(0, 2 * POS_NEG_SAMPLES, BATCH_SIZE):
                inp, target = dis_inp[i:i + BATCH_SIZE], dis_target[i:i + BATCH_SIZE]
                dis_opt.zero_grad()
                out = discriminator.batchClassify(inp)
                loss_fn = nn.BCELoss()
                loss = loss_fn(out, target)
                loss.backward()
                dis_opt.step()

                total_loss += loss.data[0]
                total_acc += torch.sum((out>0.5)==(target>0.5)).data[0]

                if (i / BATCH_SIZE) % ceil(ceil(2 * POS_NEG_SAMPLES / float(
                        BATCH_SIZE)) / 10.) == 0:
                    print('.', end='')
                    sys.stdout.flush()

            total_loss /= ceil(2 * POS_NEG_SAMPLES / float(BATCH_SIZE))
            total_acc /= float(2 * POS_NEG_SAMPLES)

            val_pred = discriminator.batchClassify(val_inp)
            print(' average_loss = %.4f, train_acc = %.4f, val_acc = %.4f' % (
                total_loss, total_acc, torch.sum((val_pred>0.5)==(val_target>0.5)).data[0]/200.))

# %%
oracle = Generator(GEN_EMBEDDING_DIM, GEN_HIDDEN_DIM, VOCAB_SIZE, MAX_SEQ_LEN, oracle_init=True)

gen = Generator(GEN_EMBEDDING_DIM, GEN_HIDDEN_DIM, VOCAB_SIZE, MAX_SEQ_LEN)
dis = Discriminator(DIS_EMBEDDING_DIM, DIS_HIDDEN_DIM, VOCAB_SIZE, MAX_SEQ_LEN)

print('Starting Generator MLE Training...')
gen_optimizer = optim.Adam(gen.parameters(), lr=1e-2)
train_generator_MLE(gen, gen_optimizer, oracle, oracle_samples, MLE_TRAIN_EPOCHS)

print('\nStarting Discriminator Training...')
dis_optimizer = optim.Adagrad(dis.parameters())
train_discriminator(dis, dis_optimizer, oracle_samples, gen, oracle, 50, 3)

print('\nStarting Adversarial Training...')
oracle_loss = helpers.batchwise_oracle_nll(gen, oracle, POS_NEG_SAMPLES, BATCH_SIZE, MAX_SEQ_LEN, start_letter=START_LETTER)
print('\nInitial Oracle Sample Loss : %.4f' % oracle_loss)

for epoch in range(ADV_TRAIN_EPOCHS):
    print('\n--------\nEPOCH %d\n--------' % (epoch+1))
    
    print('\nAdversarial Training Generator : ', end='')
    sys.stdout.flush()
    train_generator_PG(gen, gen_optimizer, oracle, dis, 1)

    print('\nAdversarial Training Discriminator : ')
    train_discriminator(dis, dis_optimizer, oracle_samples, gen, oracle, 5, 3)
# Out:
# Starting Generator MLE Training...
# epoch 1 : .......... average_train_NLL = 3.0968, oracle_sample_NLL = 9.4467
# epoch 2 : .......... average_train_NLL = 2.6100, oracle_sample_NLL = 9.4323
# epoch 3 : .......... average_train_NLL = 2.2039, oracle_sample_NLL = 9.4409
# epoch 4 : .......... average_train_NLL = 1.9153, oracle_sample_NLL = 9.3937
# epoch 5 : .......... average_train_NLL = 1.7146, oracle_sample_NLL = 9.4262
# epoch 6 : .......... average_train_NLL = 1.5662, oracle_sample_NLL = 9.4174
# epoch 7 : .......... average_train_NLL = 1.4558, oracle_sample_NLL = 9.4209
# epoch 8 : .......... average_train_NLL = 1.3716, oracle_sample_NLL = 9.3967
# epoch 9 : .......... average_train_NLL = 1.3021, oracle_sample_NLL = 9.3894
# epoch 10 : .......... average_train_NLL = 1.2471, oracle_sample_NLL = 9.4402
# epoch 11 : .......... average_train_NLL = 1.1973, oracle_sample_NLL = 9.4394
# epoch 12 : .......... average_train_NLL = 1.1565, oracle_sample_NLL = 9.4071
# epoch 13 : .......... average_train_NLL = 1.1193, oracle_sample_NLL = 9.4185
# epoch 14 : .......... average_train_NLL = 1.0850, oracle_sample_NLL = 9.4120
# epoch 15 : .......... average_train_NLL = 1.0579, oracle_sample_NLL = 9.4382
# epoch 16 : .......... average_train_NLL = 1.0307, oracle_sample_NLL = 9.3774
# epoch 17 : .......... average_train_NLL = 1.0034, oracle_sample_NLL = 9.4261
# epoch 18 : .......... average_train_NLL = 0.9817, oracle_sample_NLL = 9.3997
# epoch 19 : .......... average_train_NLL = 0.9633, oracle_sample_NLL = 9.3913
# epoch 20 : .......... average_train_NLL = 0.9470, oracle_sample_NLL = 9.4188
# epoch 21 : .......... average_train_NLL = 0.9310, oracle_sample_NLL = 9.4090
# epoch 22 : .......... average_train_NLL = 0.9164, oracle_sample_NLL = 9.4568
# epoch 23 : .......... average_train_NLL = 0.9051, oracle_sample_NLL = 9.3957
# epoch 24 : .......... average_train_NLL = 0.8893, oracle_sample_NLL = 9.4044
# epoch 25 : .......... average_train_NLL = 0.8825, oracle_sample_NLL = 9.4374
# epoch 26 : .......... average_train_NLL = 0.8698, oracle_sample_NLL = 9.4101
# epoch 27 : .......... average_train_NLL = 0.8597, oracle_sample_NLL = 9.4121
# epoch 28 : .......... average_train_NLL = 0.8522, oracle_sample_NLL = 9.4288
# epoch 29 : .......... average_train_NLL = 0.8477, oracle_sample_NLL = 9.4205
# epoch 30 : .......... average_train_NLL = 0.8356, oracle_sample_NLL = 9.4261
# epoch 31 : .......... average_train_NLL = 0.8249, oracle_sample_NLL = 9.4294
# epoch 32 : .......... average_train_NLL = 0.8222, oracle_sample_NLL = 9.4612
# epoch 33 : .......... average_train_NLL = 0.8143, oracle_sample_NLL = 9.4082
# epoch 34 : .......... average_train_NLL = 0.8029, oracle_sample_NLL = 9.3952
# epoch 35 : .......... average_train_NLL = 0.8020, oracle_sample_NLL = 9.4475
# epoch 36 : .......... average_train_NLL = 0.7989, oracle_sample_NLL = 9.4037
# epoch 37 : .......... average_train_NLL = 0.7941, oracle_sample_NLL = 9.3917
# epoch 38 : .......... average_train_NLL = 0.7856, oracle_sample_NLL = 9.3760
# epoch 39 : .......... average_train_NLL = 0.7742, oracle_sample_NLL = 9.3892
# epoch 40 : .......... average_train_NLL = 0.7721, oracle_sample_NLL = 9.3917
# epoch 41 : .......... average_train_NLL = 0.7738, oracle_sample_NLL = 9.4202
# epoch 42 : .......... average_train_NLL = 0.7727, oracle_sample_NLL = 9.3901
# epoch 43 : .......... average_train_NLL = 0.7731, oracle_sample_NLL = 9.4296
# epoch 44 : .......... average_train_NLL = 0.7712, oracle_sample_NLL = 9.4045
# epoch 45 : .......... average_train_NLL = 0.7682, oracle_sample_NLL = 9.4511
# epoch 46 : .......... average_train_NLL = 0.7605, oracle_sample_NLL = 9.4208
# epoch 47 : .......... average_train_NLL = 0.7496, oracle_sample_NLL = 9.4586
# epoch 48 : .......... average_train_NLL = 0.7447, oracle_sample_NLL = 9.4262
# epoch 49 : .......... average_train_NLL = 0.7442, oracle_sample_NLL = 9.4447
# epoch 50 : .......... average_train_NLL = 0.7447, oracle_sample_NLL = 9.3918
# epoch 51 : .......... average_train_NLL = 0.7425, oracle_sample_NLL = 9.4375
# epoch 52 : .......... average_train_NLL = 0.7445, oracle_sample_NLL = 9.4259
# epoch 53 : .......... average_train_NLL = 0.7365, oracle_sample_NLL = 9.4199
# epoch 54 : .......... average_train_NLL = 0.7358, oracle_sample_NLL = 9.3991
# epoch 55 : .......... average_train_NLL = 0.7238, oracle_sample_NLL = 9.4141
# epoch 56 : .......... average_train_NLL = 0.7221, oracle_sample_NLL = 9.4121
# epoch 57 : .......... average_train_NLL = 0.7201, oracle_sample_NLL = 9.4255
# epoch 58 : .......... average_train_NLL = 0.7148, oracle_sample_NLL = 9.3897
# epoch 59 : .......... average_train_NLL = 0.7123, oracle_sample_NLL = 9.4122
# epoch 60 : .......... average_train_NLL = 0.7210, oracle_sample_NLL = 9.4129
# epoch 61 : .......... average_train_NLL = 0.7297, oracle_sample_NLL = 9.4346
# epoch 62 : .......... average_train_NLL = 0.7287, oracle_sample_NLL = 9.4223
# epoch 63 : .......... average_train_NLL = 0.7342, oracle_sample_NLL = 9.4358
# epoch 64 : .......... average_train_NLL = 0.7369, oracle_sample_NLL = 9.4429
# epoch 65 : .......... average_train_NLL = 0.7510, oracle_sample_NLL = 9.4184
# epoch 66 : .......... average_train_NLL = 0.7440, oracle_sample_NLL = 9.4422
# epoch 67 : .......... average_train_NLL = 0.7317, oracle_sample_NLL = 9.3880
# epoch 68 : .......... average_train_NLL = 0.7303, oracle_sample_NLL = 9.4541
# epoch 69 : .......... average_train_NLL = 0.7134, oracle_sample_NLL = 9.4171
# epoch 70 : .......... average_train_NLL = 0.7052, oracle_sample_NLL = 9.4373
# epoch 71 : .......... average_train_NLL = 0.7080, oracle_sample_NLL = 9.4199
# epoch 72 : .......... average_train_NLL = 0.7003, oracle_sample_NLL = 9.4080
# epoch 73 : .......... average_train_NLL = 0.7029, oracle_sample_NLL = 9.4116
# epoch 74 : .......... average_train_NLL = 0.7012, oracle_sample_NLL = 9.4192
# epoch 75 : .......... average_train_NLL = 0.7040, oracle_sample_NLL = 9.4024
# epoch 76 : .......... average_train_NLL = 0.6986, oracle_sample_NLL = 9.3911
# epoch 77 : .......... average_train_NLL = 0.6878, oracle_sample_NLL = 9.3827
# epoch 78 : .......... average_train_NLL = 0.6845, oracle_sample_NLL = 9.4162
# epoch 79 : .......... average_train_NLL = 0.6863, oracle_sample_NLL = 9.4223
# epoch 80 : .......... average_train_NLL = 0.6847, oracle_sample_NLL = 9.4005
# epoch 81 : .......... average_train_NLL = 0.6933, oracle_sample_NLL = 9.4276
# epoch 82 : .......... average_train_NLL = 0.7030, oracle_sample_NLL = 9.3712
# epoch 83 : .......... average_train_NLL = 0.7038, oracle_sample_NLL = 9.4462
# epoch 84 : .......... average_train_NLL = 0.7216, oracle_sample_NLL = 9.4585
# epoch 85 : .......... average_train_NLL = 0.7276, oracle_sample_NLL = 9.4189
# epoch 86 : .......... average_train_NLL = 0.7196, oracle_sample_NLL = 9.4404
# epoch 87 : .......... average_train_NLL = 0.7039, oracle_sample_NLL = 9.4191
# epoch 88 : .......... average_train_NLL = 0.7156, oracle_sample_NLL = 9.4214
# epoch 89 : .......... average_train_NLL = 0.7080, oracle_sample_NLL = 9.4671
# epoch 90 : .......... average_train_NLL = 0.6922, oracle_sample_NLL = 9.4365
# epoch 91 : .......... average_train_NLL = 0.6889, oracle_sample_NLL = 9.4124
# epoch 92 : .......... average_train_NLL = 0.6964, oracle_sample_NLL = 9.4367
# epoch 93 : .......... average_train_NLL = 0.6923, oracle_sample_NLL = 9.4232
# epoch 94 : .......... average_train_NLL = 0.6926, oracle_sample_NLL = 9.4273
# epoch 95 : .......... average_train_NLL = 0.6872, oracle_sample_NLL = 9.3865
# epoch 96 : .......... average_train_NLL = 0.6972, oracle_sample_NLL = 9.4101
# epoch 97 : .......... average_train_NLL = 0.6897, oracle_sample_NLL = 9.3837
# epoch 98 : .......... average_train_NLL = 0.6771, oracle_sample_NLL = 9.4273
# epoch 99 : .......... average_train_NLL = 0.6737, oracle_sample_NLL = 9.4776
# epoch 100 : .......... average_train_NLL = 0.6754, oracle_sample_NLL = 9.3982
#
# Starting Discriminator Training...
# d-step 1 epoch 1 : .......... average_loss = 0.0503, train_acc = 0.9814, val_acc = 0.4950
# d-step 1 epoch 2 : .......... average_loss = 0.0031, train_acc = 0.9994, val_acc = 0.4950
# d-step 1 epoch 3 : .......... average_loss = 0.0007, train_acc = 1.0000, val_acc = 0.4950
# d-step 2 epoch 1 : .......... average_loss = 0.0029, train_acc = 0.9994, val_acc = 0.4950
# d-step 2 epoch 2 : .......... average_loss = 0.0005, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0003, train_acc = 1.0000, val_acc = 0.4950
# d-step 3 epoch 1 : .......... average_loss = 0.0003, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0002, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0002, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0002, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0025, train_acc = 0.9992, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0013, train_acc = 0.9996, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0002, train_acc = 1.0000, val_acc = 0.5000
# d-step 6 epoch 1 : .......... average_loss = 0.0002, train_acc = 1.0000, val_acc = 0.5000
# d-step 6 epoch 2 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 6 epoch 3 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 7 epoch 1 : .......... average_loss = 0.0003, train_acc = 0.9998, val_acc = 0.5000
# d-step 7 epoch 2 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 7 epoch 3 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 8 epoch 1 : .......... average_loss = 0.0007, train_acc = 0.9998, val_acc = 0.5000
# d-step 8 epoch 2 : .......... average_loss = 0.0002, train_acc = 1.0000, val_acc = 0.5000
# d-step 8 epoch 3 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 9 epoch 1 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 9 epoch 2 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 9 epoch 3 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 10 epoch 1 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 10 epoch 2 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 10 epoch 3 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 11 epoch 1 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 11 epoch 2 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 11 epoch 3 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 12 epoch 1 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 12 epoch 2 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 12 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 13 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 13 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 13 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 14 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 14 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 14 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 15 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 15 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 15 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 16 epoch 1 : .......... average_loss = 0.0002, train_acc = 0.9998, val_acc = 0.5000
# d-step 16 epoch 2 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 16 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 17 epoch 1 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 17 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 17 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 18 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 18 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 18 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 19 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 19 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 19 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 20 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 20 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 20 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 21 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 21 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 21 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 22 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 22 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 22 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 23 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 23 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 23 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 24 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 24 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 24 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 25 epoch 1 : .......... average_loss = 0.0017, train_acc = 0.9994, val_acc = 0.5000
# d-step 25 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 25 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 26 epoch 1 : .......... average_loss = 0.0014, train_acc = 0.9998, val_acc = 0.5000
# d-step 26 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 26 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 27 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 27 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 27 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 28 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 28 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 28 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 29 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 29 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 29 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 30 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 30 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 30 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 31 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 31 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 31 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 32 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 32 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 32 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 33 epoch 1 : .......... average_loss = 0.0005, train_acc = 0.9998, val_acc = 0.5000
# d-step 33 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 33 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 34 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 34 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 34 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 35 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 35 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 35 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 36 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 36 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 36 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 37 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 37 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 37 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 38 epoch 1 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 38 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 38 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 39 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 39 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 39 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 40 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 40 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 40 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 41 epoch 1 : .......... average_loss = 0.0015, train_acc = 0.9998, val_acc = 0.5000
# d-step 41 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 41 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 42 epoch 1 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 42 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 42 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 43 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 43 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 43 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 44 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 44 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 44 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 45 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 45 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 45 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 46 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 46 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 46 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 47 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 47 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 47 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 48 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 48 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 48 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 49 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 49 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 49 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 50 epoch 1 : .......... average_loss = 0.0001, train_acc = 1.0000, val_acc = 0.5000
# d-step 50 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 50 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# Starting Adversarial Training...
#
# Initial Oracle Sample Loss : 9.4074
#
# --------
# EPOCH 1
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.3923
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 2
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4179
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 3
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4509
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0036, train_acc = 0.9992, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0015, train_acc = 0.9998, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 4
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4139
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 5
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4328
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 6
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4316
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 7
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4063
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 8
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4533
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0003, train_acc = 0.9998, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0002, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 9
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4061
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0003, train_acc = 0.9998, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 10
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.3570
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 11
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4287
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 12
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.3982
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 13
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.3920
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 14
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4226
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 15
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4292
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 16
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4137
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0005, train_acc = 0.9998, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 17
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4251
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 18
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4322
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# ...
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 31
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4059
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 32
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4002
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 33
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4053
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 34
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4338
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 35
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4624
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 36
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4095
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 37
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4498
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 38
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4457
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 39
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4032
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 40
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4036
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 3 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 4 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 1 : .......... average_loss = 0.0005, train_acc = 0.9998, val_acc = 0.5000
# d-step 5 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 5 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
#
# --------
# EPOCH 41
# --------
#
# Adversarial Training Generator :  oracle_sample_NLL = 9.4106
#
# Adversarial Training Discriminator :
# d-step 1 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 1 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 1 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 2 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000
# d-step 2 epoch 3 : .......... average_loss = 0.0000, train_acc = 1.0000, val_acc = 0.5000

# %%
sample = gen.sample(1).view(-1,1)
words = [index2word[int(i)] for i in sample]
text = ""
for word in words:
    text += word
    text += " "
print(text)

# %%
import nltk.align.bleu
