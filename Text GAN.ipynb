# %%
from __future__ import print_function
import pdb
import math
from math import ceil
import numpy as np
import sys
import pandas as pd
import re

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F
import torch.optim as optim
import torch.autograd as autograd

import helpers

# %%
VOCAB_SIZE = 5000
MAX_SEQ_LEN = 20
START_LETTER = 0
BATCH_SIZE = 32
MLE_TRAIN_EPOCHS = 100
ADV_TRAIN_EPOCHS = 50
POS_NEG_SAMPLES = 5000

GEN_EMBEDDING_DIM = 32
GEN_HIDDEN_DIM = 32
DIS_EMBEDDING_DIM = 64
DIS_HIDDEN_DIM = 64

data_path = './donaldtrump.csv'

# %%
df = pd.DataFrame.from_csv(data_path)
df
# Out:
#                 Time                                         Tweet_Text  Type  \
# Date
# 2011-11-16  15:26:37  Today we express our deepest gratitude to all ...  text
# 2011-11-16  13:33:35  Busy day planned in New York. Will soon be mak...  text
# 2011-11-16  11:14:20  Love the fact that the small groups of protest...  text
# 2011-11-16   2:19:44  Just had a very open and successful presidenti...  text
# 2011-11-16   2:10:46  A fantastic day in D.C. Met with President Oba...  text
# 2010-11-16  19:31:27  Happy 241st birthday to the U.S. Marine Corps!...  text
# 2009-11-16  11:36:58  Such a beautiful and important evening! The fo...  text
# 2009-11-16   2:48:27  Watching the returns at 9:45pm.\n#ElectionNigh...  text
# 2009-11-16   1:35:15  RT @IvankaTrump: Such a surreal moment to vote...  text
# 2008-11-16  23:20:39  RT @EricTrump: Join my family in this incredib...  text
# 2008-11-16  23:20:09  RT @DonaldJTrumpJr: FINAL PUSH! Eric and I doi...  text
# 2008-11-16  23:03:42  Still time to #VoteTrump!\n#iVoted #ElectionNi...  text
# 2008-11-16  21:31:20  Dont let up, keep getting out to vote - this e...  text
# 2008-11-16  21:28:24  Just out according to @CNN: "Utah officials re...  text
# 2008-11-16  21:18:04  I will be watching the election results from T...  text
# 2008-11-16  18:23:39  #ElectionDay https://t.co/MXrAxYnTjY https://t...  link
# 2008-11-16  18:03:49  We need your vote. Go to the POLLS! Lets conti...  text
# 2008-11-16  16:39:36  VOTE TODAY! Go to https://t.co/MXrAxYnTjY to f...  link
# 2008-11-16  11:43:14                 TODAY WE MAKE AMERICA GREAT AGAIN!  text
# 2008-11-16   6:42:36  Today we are going to win the great state of M...  text
# 2008-11-16   4:32:51  RT @EricTrump: Sean Hannity: If Hillary wins, ...  link
# 2008-11-16   4:29:10  RT @DonaldJTrumpJr: Thanks New Hampshire!!!\n#...  text
# 2008-11-16   4:27:18  RT @detroitnews: .@IvankaTrump in Michigan: Th...  link
# 2008-11-16   3:43:54  Unbelievable evening in New Hampshire - THANK ...  text
# 2008-11-16   0:17:57  Big news to share in New Hampshire tonight! Po...  text
# 2008-11-16   0:16:15  Today in Florida, I pledged to stand with the ...  text
# 2008-11-16   0:08:28  Thank you Pennsylvania! Going to New Hampshire...  text
# 2007-11-16  23:28:48  LIVE on #Periscope: Join me for a few minutes ...  text
# 2007-11-16  22:21:53  Hey Missouri lets defeat Crooked Hillary &amp;...  text
# 2007-11-16  21:37:25  America must decide between failed policies or...  link
# ...              ...                                                ...   ...
# 2016-07-15  20:02:34  Leaving for New Hampshire now. Making a speech...  text
# 2016-07-15  19:57:10  The Iran deal poses a direct national security...  text
# 2016-07-15  19:54:31  The worst show in Las Vegas, in my opinion, is...  text
# 2016-07-15  19:49:24  Dopey @Lawrence O۪Donnell, whose unwatchable s...  text
# 2016-07-15  19:20:45  No deal is better than a bad deal. America out...  text
# 2016-07-15  19:10:27  FLASHBACK  Donald Trump Blasts Obama for Faili...  link
# 2016-07-15  18:53:43  Via @TIME by @ZekeJMiller: Trump Talks Politic...  link
# 2016-07-15  18:51:22  Via @FSMtweet: Trump is Right: Illegal Alien C...  link
# 2016-07-15  18:45:41  30,000 MACY۪S CUSTOMERS RETALIATE IN SUPPORT O...  link
# 2016-07-15  18:37:18  Is this true about Univision and Fusion? Wow!?...  link
# 2016-07-15  18:35:32  Via @BreitbartNews by Steve Bannon: ωTIME TO G...  link
# 2016-07-15  17:52:21  "@danforc  as a legal immigrant Im so glad som...  text
# 2016-07-15  17:49:11  "@ChristianInst @MorenoDadKC @BarbaraGarro The...  text
# 2016-07-15  17:40:54     They are great people! https://t.co/7RTinwz1a8  text
# 2016-07-15  17:36:17                 Thank you. https://t.co/iGNIDSqlfZ  text
# 2016-07-15  17:33:54  "@ChanRogers I literally give a fist pump when...  text
# 2016-07-15  17:31:00  "@pbstwo @RasmussenNews @realDonaldTrump @week...  text
# 2016-07-15  17:30:32  "@RasmussenNews @weeklystandard  Yea, but you ...  text
# 2016-07-15  15:20:44  "@MichaelPlu @realDonaldTrump @Macys we never ...  text
# 2016-07-15  15:02:34  .@KarlRove wasted $400 million + and didn۪t wi...  text
# 2016-07-15  15:02:03  .@FoxNews You shouldn۪t have @KarlRove on the ...  text
# 2016-07-15  14:46:22  .@BradSteinle Great talking to you and your pa...  text
# 2016-07-15  14:02:01  .@andydean2014 Thank you, you were great. You ...  text
# 2016-07-15  13:33:03   "@joshdronzek  @realDonaldTrump @Macys GO TRUMP"  text
# 2016-07-15  13:14:15  I hope the boycott of @Macys continues forever...  text
# 2016-07-15  13:10:00  I loved firing goofball atheist Penn @pennjill...  text
# 2016-07-15  10:18:31  I hear @pennjillette show on Broadway is terri...  text
# 2016-07-15  10:10:17  Irrelevant clown @KarlRove sweats and shakes n...  text
# 2016-07-15   9:44:07  "@HoustonWelder: Donald Trump is one of the se...  text
# 2016-07-15   0:21:25  RT @marklevinshow: Trump: Rove is a clown and ...  link
#
#            Media_Type                        Hashtags      Tweet_Id  \
# Date
# 2011-11-16      photo                       ThankAVet  7.970000e+17
# 2011-11-16        NaN                             NaN  7.970000e+17
# 2011-11-16        NaN                             NaN  7.970000e+17
# 2011-11-16        NaN                             NaN  7.970000e+17
# 2011-11-16        NaN                             NaN  7.970000e+17
# 2010-11-16      photo                             NaN  7.970000e+17
# 2009-11-16        NaN                             NaN  7.960000e+17
# 2009-11-16      photo              ElectionNight;MAGA  7.960000e+17
# 2009-11-16        NaN                             NaN  7.960000e+17
# 2008-11-16        NaN      MakeAmericaGreatAgain;VOTE  7.960000e+17
# 2008-11-16        NaN                MAGA;ElectionDay  7.960000e+17
# 2008-11-16      photo  VoteTrump;iVoted;ElectionNight  7.960000e+17
# 2008-11-16        NaN                             NaN  7.960000e+17
# 2008-11-16        NaN                             NaN  7.960000e+17
# 2008-11-16        NaN                             NaN  7.960000e+17
# 2008-11-16      photo                     ElectionDay  7.960000e+17
# 2008-11-16        NaN                             NaN  7.960000e+17
# 2008-11-16        NaN                             NaN  7.960000e+17
# 2008-11-16        NaN                             NaN  7.960000e+17
# 2008-11-16        NaN                             NaN  7.960000e+17
# 2008-11-16        NaN                             NaN  7.960000e+17
# 2008-11-16      photo            NH;NewHampshire;MAGA  7.960000e+17
# 2008-11-16      photo                             NaN  7.960000e+17
# 2008-11-16        NaN                             NaN  7.960000e+17
# 2008-11-16        NaN                             NaN  7.960000e+17
# 2008-11-16        NaN                             NaN  7.960000e+17
# 2008-11-16        NaN                             NaN  7.960000e+17
# 2007-11-16        NaN                  Periscope;MAGA  7.960000e+17
# 2007-11-16        NaN                             NaN  7.960000e+17
# 2007-11-16        NaN                             NaN  7.960000e+17
# ...               ...                             ...           ...
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                            Iran  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.220000e+17
# 2016-07-15        NaN                             NaN  6.210000e+17
#
#                                                     Tweet_Url  \
# Date
# 2011-11-16  https://twitter.com/realDonaldTrump/status/797...
# 2011-11-16  https://twitter.com/realDonaldTrump/status/797...
# 2011-11-16  https://twitter.com/realDonaldTrump/status/797...
# 2011-11-16  https://twitter.com/realDonaldTrump/status/796...
# 2011-11-16  https://twitter.com/realDonaldTrump/status/796...
# 2010-11-16  https://twitter.com/realDonaldTrump/status/796...
# 2009-11-16  https://twitter.com/realDonaldTrump/status/796...
# 2009-11-16  https://twitter.com/realDonaldTrump/status/796...
# 2009-11-16  https://twitter.com/realDonaldTrump/status/796...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/796...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/796...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/796...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/796...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/796...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/796...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/796...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/796...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/796...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/795...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/795...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/795...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/795...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/795...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/795...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/795...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/795...
# 2008-11-16  https://twitter.com/realDonaldTrump/status/795...
# 2007-11-16  https://twitter.com/realDonaldTrump/status/795...
# 2007-11-16  https://twitter.com/realDonaldTrump/status/795...
# 2007-11-16  https://twitter.com/realDonaldTrump/status/795...
# ...                                                       ...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
# 2016-07-15  https://twitter.com/realDonaldTrump/status/621...
#
#             twt_favourites_IS_THIS_LIKE_QUESTION_MARK  Retweets  Unnamed: 10  \
# Date
# 2011-11-16                                     127213     41112          NaN
# 2011-11-16                                     141527     28654          NaN
# 2011-11-16                                     183729     50039          NaN
# 2011-11-16                                     214001     67010          NaN
# 2011-11-16                                     178499     36688          NaN
# 2010-11-16                                     159176     44655          NaN
# 2009-11-16                                     627615    225164          NaN
# 2009-11-16                                     185160     45492          NaN
# 2009-11-16                                      99809     17169          NaN
# 2008-11-16                                      63868     19710          NaN
# 2008-11-16                                      50811     11287          NaN
# 2008-11-16                                      63750     25301          NaN
# 2008-11-16                                     116282     36745          NaN
# 2008-11-16                                      46376     21910          NaN
# 2008-11-16                                     125086     25185          NaN
# 2008-11-16                                      59198     25424          NaN
# 2008-11-16                                      61010     24310          NaN
# 2008-11-16                                      67787     29756          NaN
# 2008-11-16                                     571069    352603          NaN
# 2008-11-16                                      53730     17517          NaN
# 2008-11-16                                      20150      9176          NaN
# 2008-11-16                                      37954     10591          NaN
# 2008-11-16                                      20591      6917          NaN
# 2008-11-16                                      31321      9085          NaN
# 2008-11-16                                      43939     13453          NaN
# 2008-11-16                                      36041     13838          NaN
# 2008-11-16                                      28712      9047          NaN
# 2007-11-16                                      30569     10133          NaN
# 2007-11-16                                      36401     12556          NaN
# 2007-11-16                                      36663     16108          NaN
# ...                                               ...       ...          ...
# 2016-07-15                                       1080       279          NaN
# 2016-07-15                                       1752      1084          NaN
# 2016-07-15                                        504       204          NaN
# 2016-07-15                                        572       256          NaN
# 2016-07-15                                       1596       821          NaN
# 2016-07-15                                        752       455          NaN
# 2016-07-15                                        295       118          NaN
# 2016-07-15                                        575       356          NaN
# 2016-07-15                                        918       425          NaN
# 2016-07-15                                        334       176          NaN
# 2016-07-15                                        352       201          NaN
# 2016-07-15                                       1106       447          NaN
# 2016-07-15                                        623       329          NaN
# 2016-07-15                                        447       170          NaN
# 2016-07-15                                        928       270          NaN
# 2016-07-15                                        704       228          NaN
# 2016-07-15                                        529       191          NaN
# 2016-07-15                                        564       174          NaN
# 2016-07-15                                        472       153          NaN
# 2016-07-15                                        886       543          NaN
# 2016-07-15                                        717       415          NaN
# 2016-07-15                                        710       310          NaN
# 2016-07-15                                        356        89          NaN
# 2016-07-15                                        338       113          NaN
# 2016-07-15                                       2423      1156          NaN
# 2016-07-15                                        953       431          NaN
# 2016-07-15                                       1175      1086          NaN
# 2016-07-15                                       1494       930          NaN
# 2016-07-15                                       1800      1738          NaN
# 2016-07-15                                        962       689          NaN
#
#             Unnamed: 11
# Date
# 2011-11-16          NaN
# 2011-11-16          NaN
# 2011-11-16          NaN
# 2011-11-16          NaN
# 2011-11-16          NaN
# 2010-11-16          NaN
# 2009-11-16          NaN
# 2009-11-16          NaN
# 2009-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2008-11-16          NaN
# 2007-11-16          NaN
# 2007-11-16          NaN
# 2007-11-16          NaN
# ...                 ...
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
# 2016-07-15          NaN
#
# [7375 rows x 11 columns]

# %%
tweet_tokens = []

SOS_token = 0
EOS_token = 1
UNK_token = 2
index2word = {0: '<SOS>', 1: '<EOS>', 2: '<UNK>'}
word2index = {'<UNK>': 2}
word2count = {'<UNK>': 0}
n_words = 3

for s in df.Tweet_Text:  
    s = s.lower()
    tokens = helpers.preprocess(s)
    
    tweet_tokens.append(SOS_token)
    
    for word in tokens:
        word = re.sub(r'<[^>]+>', '<HTML>', word)
        word = re.sub(r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', '<URL>', word)
        word = re.sub(r'(?:@[\w_]+)', '<@-mentions>', word)
        if word not in word2index:
            if (n_words<VOCAB_SIZE):
                word2count[word] = 1
                word2index[word] = n_words
                index2word[n_words] = word
                n_words += 1
            else:
                word = '<UNK>'
                word2count[word] += 1
        else:
            word2count[word] += 1
            
        tweet_tokens.append(word2index[word])
        
    tweet_tokens.append(EOS_token)
test_tokens = tweet_tokens[MAX_SEQ_LEN*POS_NEG_SAMPLES+1:]
tweet_tokens = tweet_tokens[:MAX_SEQ_LEN*POS_NEG_SAMPLES]
oracle_samples = torch.LongTensor(tweet_tokens).view(POS_NEG_SAMPLES,MAX_SEQ_LEN).type(torch.LongTensor)

# %%
class Generator(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, max_seq_len, oracle_init=False):
        super(Generator, self).__init__()
        self.hidden_dim = hidden_dim
        self.embedding_dim = embedding_dim
        self.max_seq_len = max_seq_len
        self.vocab_size = vocab_size

        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.gru = nn.GRU(embedding_dim, hidden_dim)
        self.gru2out = nn.Linear(hidden_dim, vocab_size)

        if oracle_init:
            for p in self.parameters():
                init.normal(p, 0, 1)

    def init_hidden(self, batch_size=1):
        h = autograd.Variable(torch.zeros(1, batch_size, self.hidden_dim))
        return h

    def forward(self, inp, hidden):
        # input dim                                             # batch_size
        emb = self.embeddings(inp)                              # batch_size x embedding_dim
        emb = emb.view(1, -1, self.embedding_dim)               # 1 x batch_size x embedding_dim
        out, hidden = self.gru(emb, hidden)                     # 1 x batch_size x hidden_dim (out)
        out = self.gru2out(out.view(-1, self.hidden_dim))       # batch_size x vocab_size
        out = F.log_softmax(out, dim=0)
        return out, hidden

    def sample(self, num_samples, start_letter=0):

        samples = torch.zeros(num_samples, self.max_seq_len).type(torch.LongTensor)

        h = self.init_hidden(num_samples)
        inp = autograd.Variable(torch.LongTensor([start_letter]*num_samples))

        for i in range(self.max_seq_len):
            out, h = self.forward(inp, h)               # out: num_samples x vocab_size
            out = torch.multinomial(torch.exp(out), 1)  # num_samples x 1 (sampling from each row)
            samples[:, i] = out.data

            inp = out.view(-1)

        return samples

    def batchNLLLoss(self, inp, target):
        loss_fn = nn.NLLLoss()
        batch_size, seq_len = inp.size()
        inp = inp.permute(1, 0)           # seq_len x batch_size
        target = target.permute(1, 0)     # seq_len x batch_size
        h = self.init_hidden(batch_size)

        loss = 0
        for i in range(seq_len):
            out, h = self.forward(inp[i], h)
            loss += loss_fn(out, target[i])

        return loss     # per batch

    def batchPGLoss(self, inp, target, reward):
        batch_size, seq_len = inp.size()
        inp = inp.permute(1, 0)          # seq_len x batch_size
        target = target.permute(1, 0)    # seq_len x batch_size
        h = self.init_hidden(batch_size)

        loss = 0
        for i in range(seq_len):
            out, h = self.forward(inp[i], h)
            for j in range(batch_size):
                loss += -out[j][target.data[i][j]]*reward[j]     # log(P(y_t|Y_1:Y_{t-1})) * Q

        return loss/batch_size

# %%
class Discriminator(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, max_seq_len, dropout=0.2):
        super(Discriminator, self).__init__()
        self.hidden_dim = hidden_dim
        self.embedding_dim = embedding_dim
        self.max_seq_len = max_seq_len

        self.embeddings = nn.Embedding(vocab_size, embedding_dim)
        self.gru = nn.GRU(embedding_dim, hidden_dim, num_layers=2, bidirectional=True, dropout=dropout)
        self.gru2hidden = nn.Linear(2*2*hidden_dim, hidden_dim)
        self.dropout_linear = nn.Dropout(p=dropout)
        self.hidden2out = nn.Linear(hidden_dim, 1)

    def init_hidden(self, batch_size):
        h = autograd.Variable(torch.zeros(2*2*1, batch_size, self.hidden_dim))
        return h

    def forward(self, input, hidden):
        # input dim                                                # batch_size x seq_len
        emb = self.embeddings(input)                               # batch_size x seq_len x embedding_dim
        emb = emb.permute(1, 0, 2)                                 # seq_len x batch_size x embedding_dim
        _, hidden = self.gru(emb, hidden)                          # 4 x batch_size x hidden_dim
        hidden = hidden.permute(1, 0, 2).contiguous()              # batch_size x 4 x hidden_dim
        out = self.gru2hidden(hidden.view(-1, 4*self.hidden_dim))  # batch_size x 4*hidden_dim
        out = F.tanh(out)
        out = self.dropout_linear(out)
        out = self.hidden2out(out)                                 # batch_size x 1
        out = F.sigmoid(out)
        return out

    def batchClassify(self, inp):
        h = self.init_hidden(inp.size()[0])
        out = self.forward(inp, h)
        return out.view(-1)

    def batchBCELoss(self, inp, target):
        loss_fn = nn.BCELoss()
        h = self.init_hidden(inp.size()[0])
        out = self.forward(inp, h)
        return loss_fn(out, target)

# %%
def train_generator_MLE(gen, gen_opt, oracle, real_data_samples, epochs):
    for epoch in range(epochs):
        print('epoch %d : ' % (epoch + 1), end='')
        sys.stdout.flush()
        total_loss = 0

        for i in range(0, POS_NEG_SAMPLES, BATCH_SIZE):
            inp, target = helpers.prepare_generator_batch(real_data_samples[i:i + BATCH_SIZE], start_letter=START_LETTER)
            gen_opt.zero_grad()
            loss = gen.batchNLLLoss(inp, target)
            loss.backward()
            gen_opt.step()

            total_loss += loss.data[0]

            if (i / BATCH_SIZE) % ceil(
                            ceil(POS_NEG_SAMPLES / float(BATCH_SIZE)) / 10.) == 0:  # roughly every 10% of an epoch
                print('.', end='')
                sys.stdout.flush()
                
        total_loss = total_loss / ceil(POS_NEG_SAMPLES / float(BATCH_SIZE)) / MAX_SEQ_LEN
        oracle_loss = helpers.batchwise_oracle_nll(gen, oracle, POS_NEG_SAMPLES, BATCH_SIZE, MAX_SEQ_LEN, start_letter=START_LETTER)

        print(' average_train_NLL = %.4f, oracle_sample_NLL = %.4f' % (total_loss, oracle_loss))

# %%
def train_generator_PG(gen, gen_opt, oracle, dis, num_batches):
    for batch in range(num_batches):
        s = gen.sample(BATCH_SIZE*2)
        inp, target = helpers.prepare_generator_batch(s, start_letter=START_LETTER)
        rewards = dis.batchClassify(target)

        gen_opt.zero_grad()
        pg_loss = gen.batchPGLoss(inp, target, rewards)
        pg_loss.backward()
        gen_opt.step()
        
    oracle_loss = helpers.batchwise_oracle_nll(gen, oracle, POS_NEG_SAMPLES, BATCH_SIZE, MAX_SEQ_LEN, start_letter=START_LETTER)

    print(' oracle_sample_NLL = %.4f' % oracle_loss)

# %%
def train_discriminator(discriminator, dis_opt, real_data_samples, generator, oracle, d_steps, epochs):
    pos_val = oracle.sample(100)
    neg_val = generator.sample(100)
    val_inp, val_target = helpers.prepare_discriminator_data(pos_val, neg_val)

    for d_step in range(d_steps):
        s = helpers.batchwise_sample(generator, POS_NEG_SAMPLES, BATCH_SIZE)
        dis_inp, dis_target = helpers.prepare_discriminator_data(real_data_samples, s)
        for epoch in range(epochs):
            print('d-step %d epoch %d : ' % (d_step + 1, epoch + 1), end='')
            sys.stdout.flush()
            total_loss = 0
            total_acc = 0

            for i in range(0, 2 * POS_NEG_SAMPLES, BATCH_SIZE):
                inp, target = dis_inp[i:i + BATCH_SIZE], dis_target[i:i + BATCH_SIZE]
                dis_opt.zero_grad()
                out = discriminator.batchClassify(inp)
                loss_fn = nn.BCELoss()
                loss = loss_fn(out, target)
                loss.backward()
                dis_opt.step()

                total_loss += loss.data[0]
                total_acc += torch.sum((out>0.5)==(target>0.5)).data[0]

                if (i / BATCH_SIZE) % ceil(ceil(2 * POS_NEG_SAMPLES / float(
                        BATCH_SIZE)) / 10.) == 0:
                    print('.', end='')
                    sys.stdout.flush()

            total_loss /= ceil(2 * POS_NEG_SAMPLES / float(BATCH_SIZE))
            total_acc /= float(2 * POS_NEG_SAMPLES)

            val_pred = discriminator.batchClassify(val_inp)
            print(' average_loss = %.4f, train_acc = %.4f, val_acc = %.4f' % (
                total_loss, total_acc, torch.sum((val_pred>0.5)==(val_target>0.5)).data[0]/200.))

# %%
oracle = Generator(GEN_EMBEDDING_DIM, GEN_HIDDEN_DIM, VOCAB_SIZE, MAX_SEQ_LEN, oracle_init=True)

gen = Generator(GEN_EMBEDDING_DIM, GEN_HIDDEN_DIM, VOCAB_SIZE, MAX_SEQ_LEN)
dis = Discriminator(DIS_EMBEDDING_DIM, DIS_HIDDEN_DIM, VOCAB_SIZE, MAX_SEQ_LEN)

print('Starting Generator MLE Training...')
gen_optimizer = optim.Adam(gen.parameters(), lr=1e-2)
train_generator_MLE(gen, gen_optimizer, oracle, oracle_samples, MLE_TRAIN_EPOCHS)

#print('\nStarting Discriminator Training...')
#dis_optimizer = optim.Adagrad(dis.parameters())
#train_discriminator(dis, dis_optimizer, oracle_samples, gen, oracle, 50, 3)
#
#print('\nStarting Adversarial Training...')
#oracle_loss = helpers.batchwise_oracle_nll(gen, oracle, POS_NEG_SAMPLES, BATCH_SIZE, MAX_SEQ_LEN, start_letter=START_LETTER)
#print('\nInitial Oracle Sample Loss : %.4f' % oracle_loss)
#
#for epoch in range(ADV_TRAIN_EPOCHS):
#    print('\n--------\nEPOCH %d\n--------' % (epoch+1))
#    
#    print('\nAdversarial Training Generator : ', end='')
#    sys.stdout.flush()
#    train_generator_PG(gen, gen_optimizer, oracle, dis, 1)
#
#    print('\nAdversarial Training Discriminator : ')
#    train_discriminator(dis, dis_optimizer, oracle_samples, gen, oracle, 5, 3)
# Out:
# Starting Generator MLE Training...
# epoch 1 : .......... average_train_NLL = 2.8151, oracle_sample_NLL = 9.5380
# epoch 2 : .......... average_train_NLL = 2.3287, oracle_sample_NLL = 9.5161
# epoch 3 : .......... average_train_NLL = 2.0794, oracle_sample_NLL = 9.5248
# epoch 4 : .......... average_train_NLL = 1.9295, oracle_sample_NLL = 9.5216
# epoch 5 : .......... average_train_NLL = 1.8312, oracle_sample_NLL = 9.5259
# epoch 6 : .......... average_train_NLL = 1.7589, oracle_sample_NLL = 9.5179
# epoch 7 : .......... average_train_NLL = 1.7033, oracle_sample_NLL = 9.4839
# epoch 8 : .......... average_train_NLL = 1.6596, oracle_sample_NLL = 9.5177
# epoch 9 : .......... average_train_NLL = 1.6253, oracle_sample_NLL = 9.5333
# epoch 10 : .......... average_train_NLL = 1.5966, oracle_sample_NLL = 9.5360
# epoch 11 : .......... average_train_NLL = 1.5712, oracle_sample_NLL = 9.5460
# epoch 12 : .......... average_train_NLL = 1.5500, oracle_sample_NLL = 9.4838
# epoch 13 : .......... average_train_NLL = 1.5285, oracle_sample_NLL = 9.5144
# epoch 14 : .......... average_train_NLL = 1.5170, oracle_sample_NLL = 9.5267
# epoch 15 : .......... average_train_NLL = 1.4997, oracle_sample_NLL = 9.5248
# epoch 16 : .......... average_train_NLL = 1.4863, oracle_sample_NLL = 9.5178
# epoch 17 : .......... average_train_NLL = 1.4765, oracle_sample_NLL = 9.5161
# epoch 18 : .......... average_train_NLL = 1.4673, oracle_sample_NLL = 9.5134
# epoch 19 : .......... average_train_NLL = 1.4589, oracle_sample_NLL = 9.4971
# epoch 20 : .......... average_train_NLL = 1.4520, oracle_sample_NLL = 9.5351
# epoch 21 : .......... average_train_NLL = 1.4409, oracle_sample_NLL = 9.5079
# epoch 22 : .......... average_train_NLL = 1.4322, oracle_sample_NLL = 9.5110
# epoch 23 : .......... average_train_NLL = 1.4256, oracle_sample_NLL = 9.5291
# epoch 24 : .......... average_train_NLL = 1.4175, oracle_sample_NLL = 9.5140
# epoch 25 : .......... average_train_NLL = 1.4093, oracle_sample_NLL = 9.5173
# epoch 26 : .......... average_train_NLL = 1.4078, oracle_sample_NLL = 9.5119
# epoch 27 : .......... average_train_NLL = 1.3988, oracle_sample_NLL = 9.5038
# epoch 28 : .......... average_train_NLL = 1.3946, oracle_sample_NLL = 9.5103
# epoch 29 : .......... average_train_NLL = 1.3940, oracle_sample_NLL = 9.5185
# epoch 30 : .......... average_train_NLL = 1.3893, oracle_sample_NLL = 9.5447
# epoch 31 : .......... average_train_NLL = 1.3891, oracle_sample_NLL = 9.5408
# epoch 32 : .......... average_train_NLL = 1.3830, oracle_sample_NLL = 9.5427
# epoch 33 : .......... average_train_NLL = 1.3802, oracle_sample_NLL = 9.4932
# epoch 34 : .......... average_train_NLL = 1.3740, oracle_sample_NLL = 9.5309
# epoch 35 : .......... average_train_NLL = 1.3715, oracle_sample_NLL = 9.5250
# epoch 36 : .......... average_train_NLL = 1.3669, oracle_sample_NLL = 9.5151
# epoch 37 : .......... average_train_NLL = 1.3636, oracle_sample_NLL = 9.5234
# epoch 38 : .......... average_train_NLL = 1.3635, oracle_sample_NLL = 9.5118
# epoch 39 : .......... average_train_NLL = 1.3724, oracle_sample_NLL = 9.4994
# epoch 40 : .......... average_train_NLL = 1.3719, oracle_sample_NLL = 9.5309
# epoch 41 : .......... average_train_NLL = 1.3619, oracle_sample_NLL = 9.4931
# epoch 42 : .......... average_train_NLL = 1.3576, oracle_sample_NLL = 9.5054
# epoch 43 : .......... average_train_NLL = 1.3570, oracle_sample_NLL = 9.4917
# epoch 44 : .......... average_train_NLL = 1.3471, oracle_sample_NLL = 9.5244
# epoch 45 : .......... average_train_NLL = 1.3416, oracle_sample_NLL = 9.5217
# epoch 46 : .......... average_train_NLL = 1.3496, oracle_sample_NLL = 9.5215
# epoch 47 : .......... average_train_NLL = 1.3520, oracle_sample_NLL = 9.5041
# epoch 48 : .......... average_train_NLL = 1.3523, oracle_sample_NLL = 9.5344
# epoch 49 : .......... average_train_NLL = 1.3403, oracle_sample_NLL = 9.5105
# epoch 50 : .......... average_train_NLL = 1.3381, oracle_sample_NLL = 9.5343
# epoch 51 : .......... average_train_NLL = 1.3467, oracle_sample_NLL = 9.5073
# epoch 52 : .......... average_train_NLL = 1.3488, oracle_sample_NLL = 9.5134
# epoch 53 : .......... average_train_NLL = 1.3464, oracle_sample_NLL = 9.5280
# epoch 54 : .......... average_train_NLL = 1.3375, oracle_sample_NLL = 9.5145
# epoch 55 : .......... average_train_NLL = 1.3312, oracle_sample_NLL = 9.5198
# epoch 56 : .......... average_train_NLL = 1.3311, oracle_sample_NLL = 9.5301
# epoch 57 : .......... average_train_NLL = 1.3387, oracle_sample_NLL = 9.5195
# epoch 58 : .......... average_train_NLL = 1.3376, oracle_sample_NLL = 9.5290
# epoch 59 : .......... average_train_NLL = 1.3274, oracle_sample_NLL = 9.5150
# epoch 60 : .......... average_train_NLL = 1.3246, oracle_sample_NLL = 9.4823
# epoch 61 : .......... average_train_NLL = 1.3246, oracle_sample_NLL = 9.5437
# epoch 62 : .......... average_train_NLL = 1.3246, oracle_sample_NLL = 9.4918
# epoch 63 : .......... average_train_NLL = 1.3322, oracle_sample_NLL = 9.4947
# epoch 64 : .......... average_train_NLL = 1.3317, oracle_sample_NLL = 9.5151
# epoch 65 : .......... average_train_NLL = 1.3347, oracle_sample_NLL = 9.5267
# epoch 66 : .......... average_train_NLL = 1.3304, oracle_sample_NLL = 9.5288
# epoch 67 : .......... average_train_NLL = 1.3486, oracle_sample_NLL = 9.5070
# epoch 68 : .......... average_train_NLL = 1.3334, oracle_sample_NLL = 9.4924
# epoch 69 : .......... average_train_NLL = 1.3341, oracle_sample_NLL = 9.5084
# epoch 70 : .......... average_train_NLL = 1.3287, oracle_sample_NLL = 9.5173
# epoch 71 : .......... average_train_NLL = 1.3313, oracle_sample_NLL = 9.4783
# epoch 72 : .......... average_train_NLL = 1.3309, oracle_sample_NLL = 9.5447
# epoch 73 : .......... average_train_NLL = 1.3098, oracle_sample_NLL = 9.5333
# epoch 74 : .......... average_train_NLL = 1.3151, oracle_sample_NLL = 9.4989
# epoch 75 : .......... average_train_NLL = 1.3339, oracle_sample_NLL = 9.4931
# epoch 76 : .......... average_train_NLL = 1.3499, oracle_sample_NLL = 9.5381
# epoch 77 : .......... average_train_NLL = 1.3526, oracle_sample_NLL = 9.5204
# epoch 78 : .......... average_train_NLL = 1.3541, oracle_sample_NLL = 9.5477
# epoch 79 : .......... average_train_NLL = 1.3425, oracle_sample_NLL = 9.5041
# epoch 80 : .......... average_train_NLL = 1.3222, oracle_sample_NLL = 9.5390
# epoch 81 : .......... average_train_NLL = 1.3123, oracle_sample_NLL = 9.4974
# epoch 82 : .......... average_train_NLL = 1.3125, oracle_sample_NLL = 9.5182
# epoch 83 : .......... average_train_NLL = 1.3158, oracle_sample_NLL = 9.5076
# epoch 84 : .......... average_train_NLL = 1.3302, oracle_sample_NLL = 9.5075
# epoch 85 : .......... average_train_NLL = 1.3215, oracle_sample_NLL = 9.5223
# epoch 86 : .......... average_train_NLL = 1.3350, oracle_sample_NLL = 9.5137
# epoch 87 : .......... average_train_NLL = 1.3249, oracle_sample_NLL = 9.5001
# epoch 88 : .......... average_train_NLL = 1.3257, oracle_sample_NLL = 9.5308
# epoch 89 : .......... average_train_NLL = 1.3267, oracle_sample_NLL = 9.5322
# epoch 90 : .......... average_train_NLL = 1.3306, oracle_sample_NLL = 9.5226
# epoch 91 : .......... average_train_NLL = 1.3190, oracle_sample_NLL = 9.5083
# epoch 92 : .......... average_train_NLL = 1.3609, oracle_sample_NLL = 9.5360
# epoch 93 : .......... average_train_NLL = 1.3730, oracle_sample_NLL = 9.4931
# epoch 94 : .......... average_train_NLL = 1.3484, oracle_sample_NLL = 9.5222
# epoch 95 : .......... average_train_NLL = 1.3458, oracle_sample_NLL = 9.5349
# epoch 96 : .......... average_train_NLL = 1.3252, oracle_sample_NLL = 9.5301
# epoch 97 : .......... average_train_NLL = 1.3195, oracle_sample_NLL = 9.5442
# epoch 98 : .......... average_train_NLL = 1.3096, oracle_sample_NLL = 9.5140
# epoch 99 : .......... average_train_NLL = 1.3130, oracle_sample_NLL = 9.5338
# epoch 100 : .......... average_train_NLL = 1.3064, oracle_sample_NLL = 9.5262

# %%
sample = gen.sample(1).view(-1,1)
words = [index2word[int(i)] for i in sample]
text = ""
for word in words:
    text += word
    text += " "
print(text)
# Out:
# disenfranchised dear opposed visit smoothly islamic based blue-collar therefore director est two-man strictly platforms brutal atlanta opo palazzo companies nafta
